# %% [markdown]
# # Setup

# %%
import itertools
from collections import defaultdict

import torch
import numpy as np
from monai.metrics import compute_hausdorff_distance
import torch.nn.functional as F
import matplotlib.pyplot as plt
import einops as E
from torch.utils.data import DataLoader

import utils.dataset as example_data
from utils.visualization import visualize_tensors
from utils.utils import seed_everything
from models.original_universeg import universeg
from models.original_universeg import SimpleUniverSeg
import math
import itertools

from tqdm.auto import tqdm
import numpy as np
import matplotlib.pyplot as plt

import einops as E
import pathlib
import subprocess
from dataclasses import dataclass
from utils.const import DATA_FOLDER
from typing import Literal, Tuple

import numpy as np
import nibabel as nib
import PIL
import torch
from torch.utils.data import Dataset
import monai.losses

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = universeg(pretrained=False).to(device)

# %%
def visualize_tensors(tensors, col_wrap=8, col_names=None, title=None):
    M = len(tensors)
    N = len(next(iter(tensors.values())))

    cols = col_wrap
    rows = math.ceil(N/cols) * M

    d = 2.5
    fig, axes = plt.subplots(rows, cols, figsize=(d*cols, d*rows))
    if rows == 1:
      axes = axes.reshape(1, cols)

    for g, (grp, tensors) in enumerate(tensors.items()):
        for k, tensor in enumerate(tensors):
            col = k % cols
            row = g + M*(k//cols)
            x = tensor.detach().cpu().numpy().squeeze()
            ax = axes[row,col]
            if len(x.shape) == 2:
                ax.imshow(x,vmin=0, vmax=1, cmap='gray')
            else:
                ax.imshow(E.rearrange(x,'C H W -> H W C'))
            if col == 0:
                ax.set_ylabel(grp, fontsize=16)
            if col_names is not None and row == 0:
                ax.set_title(col_names[col])

    for i in range(rows):
        for j in range(cols):
            ax = axes[i,j]
            ax.grid(False)
            ax.set_xticks([])
            ax.set_yticks([])

    if title:
        plt.suptitle(title, fontsize=20)

    plt.tight_layout()

# %%
def dice_score(y_pred: torch.Tensor, y_true: torch.Tensor) -> float:
    y_pred = y_pred.long()
    y_true = y_true.long()
    score = 2*(y_pred*y_true).sum() / (y_pred.sum() + y_true.sum())
    return score.item()

# %% [markdown]
# # Data Set

# %%
# supportloader = DataLoader(d_support, batch_size=32, shuffle=False, num_workers=1)
# testloader = DataLoader(d_test, batch_size=32, shuffle=False, num_workers=1)
# devloader = DataLoader(d_dev, batch_size=32, shuffle=False, num_workers=1)

# %%
lr = 10e-4
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
dice_loss = monai.losses.DiceLoss()
max_epoch = 100
support_set_sizes = [1, 2, 4, 8, 16, 32, 64]
val_interval = 1
support_set_size = 32
BATCH_SIZE = 2

# %%
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
for epoch in range(max_epoch):
    model.train()
    epoch_loss = 0
    step = 0
    task_idx = np.random.randint(20)
    d_support = example_data.My_OASISDataset("support", task_idx)
    supportloader = DataLoader(d_support, batch_size=BATCH_SIZE, shuffle=False, num_workers=1)
    for batch_data, batch_indices in zip(supportloader, supportloader.batch_sampler):
        step += 1
        image, labels = batch_data[0].to(device), batch_data[1].to(device)
        support_set = [element for idx, element in enumerate(d_support) if idx not in batch_indices]

        support_images, support_labels = zip(*itertools.islice(support_set, support_set_size*BATCH_SIZE))
        support_images = torch.stack(support_images).view(BATCH_SIZE, support_set_size, 1, 128, 128).to(device)
        support_labels = torch.stack(support_labels).view(BATCH_SIZE, support_set_size, 1, 128, 128).to(device)
        optimizer.zero_grad()

        logits = model(image, support_images, support_labels)
        pred = torch.sigmoid(logits)
        loss = dice_loss(pred, labels)
        loss.backward()
        epoch_loss += loss.item()        
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
    
    if (epoch + 1) % val_interval == 0:
        model.eval()
        d_dev = example_data.My_OASISDataset("dev", task_idx)
        devloader = DataLoader(d_dev, batch_size=BATCH_SIZE, shuffle=False, num_workers=1)
        score = []
        with torch.no_grad():
            y_pred = torch.tensor([], dtype = torch.float32, device = device)
            y = torch.tensor([], dtype = torch.long, device = device)
            for dev_data, dev_indices in zip(devloader, devloader.batch_sampler):
                dev_image, dev_label = (dev_data[0].to(device), dev_data[1].to(device))
                dev_support = [element for idx, element in enumerate(d_dev) if idx not in dev_indices]

                dev_support_images, dev_support_labels = zip(*itertools.islice(dev_support, support_set_size*BATCH_SIZE))
                dev_support_images = torch.stack(dev_support_images).view(BATCH_SIZE, support_set_size, 1, 128, 128).to(device)
                dev_support_labels = torch.stack(dev_support_labels).view(BATCH_SIZE, support_set_size, 1, 128, 128).to(device)

                dev_logits = model(dev_image, dev_support_images, dev_support_labels)
                dev_soft_pred = torch.sigmoid(dev_logits)
                dev_hard_pred = dev_soft_pred.round().clip(0,1)
                score.append(dice_score(dev_hard_pred, dev_label))
                # y_pred = torch.cat([y_pred, dev_hard_pred], dim=0)
                # y = torch.cat([y, dev_label], dim = 0)
            result = sum(score) / len(score)
            # if result > best_metric:
            #     best_metric = result
            #     best_metric_epoch = epoch + 1
            #     torch.save(model.state_dict(), os.path.join(root_dir, "best_metric_model.pth"))
            #     print("saved new best metric model")
            print(f"current epoch: {epoch + 1}" f" current dice score: {result:.4f}")
# Out:
# epoch 1 average loss: 0.9976
# current epoch: 1 current dice score: 0.0004
# epoch 2 average loss: 0.9974
# current epoch: 2 current dice score: 0.0014
# epoch 3 average loss: 0.9872
# current epoch: 3 current dice score: 0.0051
# epoch 4 average loss: 0.9967
# current epoch: 4 current dice score: 0.0011
# epoch 5 average loss: 0.9817
# current epoch: 5 current dice score: 0.0142
# epoch 6 average loss: 0.9859
# current epoch: 6 current dice score: 0.0056
# epoch 7 average loss: 0.9816
# current epoch: 7 current dice score: 0.0033
# epoch 8 average loss: 0.9993
# current epoch: 8 current dice score: 0.0000
# epoch 9 average loss: 0.9816
# current epoch: 9 current dice score: 0.0033
# epoch 10 average loss: 0.9816
# current epoch: 10 current dice score: 0.0033
# epoch 11 average loss: 0.9976
# current epoch: 11 current dice score: 0.0004
# epoch 12 average loss: 0.9816
# current epoch: 12 current dice score: 0.0033
# epoch 13 average loss: 0.9934
# current epoch: 13 current dice score: 0.0035
# epoch 14 average loss: 0.9985
# current epoch: 14 current dice score: 0.0000
# epoch 15 average loss: 0.9859
# current epoch: 15 current dice score: 0.0056
# epoch 16 average loss: 0.9980
# current epoch: 16 current dice score: 0.0035
# epoch 17 average loss: 0.9967
# current epoch: 17 current dice score: 0.0011
# epoch 18 average loss: 0.9864
# current epoch: 18 current dice score: 0.0071
# epoch 19 average loss: 0.8868
# current epoch: 19 current dice score: 0.0055
# epoch 20 average loss: 0.8668
# current epoch: 20 current dice score: 0.0177
# epoch 21 average loss: 0.9816
# current epoch: 21 current dice score: 0.0033
# epoch 22 average loss: 0.8696
# current epoch: 22 current dice score: 0.0249
# epoch 23 average loss: 0.9817
# current epoch: 23 current dice score: 0.0142
# epoch 24 average loss: 0.9985
# current epoch: 24 current dice score: 0.0000
# epoch 25 average loss: 0.8868
# current epoch: 25 current dice score: 0.0055
# epoch 26 average loss: 0.9859
# current epoch: 26 current dice score: 0.0056
# epoch 27 average loss: 0.9900
# current epoch: 27 current dice score: 0.0002
# epoch 28 average loss: 0.9974
# current epoch: 28 current dice score: 0.0014
# epoch 29 average loss: 0.9864
# current epoch: 29 current dice score: 0.0071
# epoch 30 average loss: 0.9976
# current epoch: 30 current dice score: 0.0007
# epoch 31 average loss: 0.9849
# current epoch: 31 current dice score: 0.0098
# epoch 32 average loss: 0.9816
# current epoch: 32 current dice score: 0.0033
# epoch 33 average loss: 0.9976
# current epoch: 33 current dice score: 0.0004
# epoch 34 average loss: 0.9967
# current epoch: 34 current dice score: 0.0011
# epoch 35 average loss: 0.8668
# current epoch: 35 current dice score: 0.0177
# epoch 36 average loss: 0.8868
# current epoch: 36 current dice score: 0.0055
# epoch 37 average loss: 0.9849
# current epoch: 37 current dice score: 0.0081
# epoch 38 average loss: 0.9934
# current epoch: 38 current dice score: 0.0035
# epoch 39 average loss: 0.8668
# current epoch: 39 current dice score: 0.0177
# epoch 40 average loss: 0.9934
# current epoch: 40 current dice score: 0.0035
# epoch 41 average loss: 0.4794
# current epoch: 41 current dice score: 0.1163
# epoch 42 average loss: 0.8868
# current epoch: 42 current dice score: 0.0055
# epoch 43 average loss: 0.8857
# current epoch: 43 current dice score: 0.0083
# epoch 44 average loss: 0.8668
# current epoch: 44 current dice score: 0.0177
# epoch 45 average loss: 0.8696
# current epoch: 45 current dice score: 0.0249
# epoch 46 average loss: 0.9980
# current epoch: 46 current dice score: 0.0035
# epoch 47 average loss: 0.8696
# current epoch: 47 current dice score: 0.0249
# epoch 48 average loss: 0.9967
# current epoch: 48 current dice score: 0.0011
# epoch 49 average loss: 0.9849
# current epoch: 49 current dice score: 0.0081
# epoch 50 average loss: 0.9859
# current epoch: 50 current dice score: 0.0056
# epoch 51 average loss: 0.8868
# current epoch: 51 current dice score: 0.0055
# epoch 52 average loss: 0.8868
# current epoch: 52 current dice score: 0.0055
# epoch 53 average loss: 0.9993
# current epoch: 53 current dice score: 0.0000
# epoch 54 average loss: 0.9985
# current epoch: 54 current dice score: 0.0000
# epoch 55 average loss: 0.8857
# current epoch: 55 current dice score: 0.0083
# epoch 56 average loss: 0.9976
# current epoch: 56 current dice score: 0.0004
# epoch 57 average loss: 0.9974
# current epoch: 57 current dice score: 0.0014
# epoch 58 average loss: 0.9985
# current epoch: 58 current dice score: 0.0000
# epoch 59 average loss: 0.9976
# current epoch: 59 current dice score: 0.0007
# epoch 60 average loss: 0.9974
# current epoch: 60 current dice score: 0.0014
# epoch 61 average loss: 0.9816
# current epoch: 61 current dice score: 0.0033
# epoch 62 average loss: 0.4794
# current epoch: 62 current dice score: 0.1163
# epoch 63 average loss: 0.8857
# current epoch: 63 current dice score: 0.0083
# epoch 64 average loss: 0.9894
# current epoch: 64 current dice score: 0.0003
# epoch 65 average loss: 0.9816
# current epoch: 65 current dice score: 0.0033
# epoch 66 average loss: 0.9859
# current epoch: 66 current dice score: 0.0056
# epoch 67 average loss: 0.9816
# current epoch: 67 current dice score: 0.0033
# epoch 68 average loss: 0.9980
# current epoch: 68 current dice score: 0.0035
# epoch 69 average loss: 0.9849
# current epoch: 69 current dice score: 0.0081
# epoch 70 average loss: 0.8868
# current epoch: 70 current dice score: 0.0055
# epoch 71 average loss: 0.8857
# current epoch: 71 current dice score: 0.0083
# epoch 72 average loss: 0.8857
# current epoch: 72 current dice score: 0.0083
# epoch 73 average loss: 0.9849
# current epoch: 73 current dice score: 0.0098
# epoch 74 average loss: 0.8868
# current epoch: 74 current dice score: 0.0055
# epoch 75 average loss: 0.9817
# current epoch: 75 current dice score: 0.0142
# epoch 76 average loss: 0.9934
# current epoch: 76 current dice score: 0.0035
# epoch 77 average loss: 0.9974
# current epoch: 77 current dice score: 0.0014
# epoch 78 average loss: 0.8668
# current epoch: 78 current dice score: 0.0177
# epoch 79 average loss: 0.9976
# current epoch: 79 current dice score: 0.0004
# epoch 80 average loss: 0.9974
# current epoch: 80 current dice score: 0.0014
# epoch 81 average loss: 0.9976
# current epoch: 81 current dice score: 0.0004
# epoch 82 average loss: 0.9816
# current epoch: 82 current dice score: 0.0033
# epoch 83 average loss: 0.4794
# current epoch: 83 current dice score: 0.1163
# epoch 84 average loss: 0.9980
# current epoch: 84 current dice score: 0.0035
# epoch 85 average loss: 0.9976
# current epoch: 85 current dice score: 0.0007
# epoch 86 average loss: 0.9900
# current epoch: 86 current dice score: 0.0002
# epoch 87 average loss: 0.9944
# current epoch: 87 current dice score: 0.0030
# epoch 88 average loss: 0.9934
# current epoch: 88 current dice score: 0.0035
# epoch 89 average loss: 0.9872
# current epoch: 89 current dice score: 0.0051
# epoch 90 average loss: 0.8696
# current epoch: 90 current dice score: 0.0249
# epoch 91 average loss: 0.9993
# current epoch: 91 current dice score: 0.0000
# epoch 92 average loss: 0.9967
# current epoch: 92 current dice score: 0.0011
# epoch 93 average loss: 0.4794
# current epoch: 93 current dice score: 0.1163
# epoch 94 average loss: 0.8668
# current epoch: 94 current dice score: 0.0177
# epoch 95 average loss: 0.9985
# current epoch: 95 current dice score: 0.0000
# epoch 96 average loss: 0.9967
# current epoch: 96 current dice score: 0.0011
# epoch 97 average loss: 0.9967
# current epoch: 97 current dice score: 0.0011
# epoch 98 average loss: 0.9985
# current epoch: 98 current dice score: 0.0000
# epoch 99 average loss: 0.9984
# current epoch: 99 current dice score: 0.0002
# epoch 100 average loss: 0.9974
# current epoch: 100 current dice score: 0.0014
